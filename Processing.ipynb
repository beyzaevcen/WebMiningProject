# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv("series_by_year.csv")

# %%
df
# Out:
#                                     name  rating  year  \
# 0                         Because of You     7.0  2010
# 1     My Girlfriend is a Nine-Tailed Fox     8.5  2010
# 2                                P.S Man     6.3  2010
# 3                       A Man Called God     6.7  2010
# 4                                  Pasta     7.4  2010
# ...                                  ...     ...   ...
# 1003                          Flex X Cop     9.1  2024
# 1004                 The Midnight Studio     8.0  2024
# 1005                      Queen of Tears     8.6  2024
# 1006                        Pyramid Game     8.7  2024
# 1007                        Doctor Slump     8.4  2024
#
#                                                     url
# 0     https://asyafanatiklerim.com/dizi/because-of-you/
# 1     https://asyafanatiklerim.com/dizi/my-girlfrien...
# 2            https://asyafanatiklerim.com/dizi/p-s-man/
# 3     https://asyafanatiklerim.com/dizi/a-man-called...
# 4              https://asyafanatiklerim.com/dizi/pasta/
# ...                                                 ...
# 1003      https://asyafanatiklerim.com/dizi/flex-x-cop/
# 1004  https://asyafanatiklerim.com/dizi/the-midnight...
# 1005  https://asyafanatiklerim.com/dizi/queen-of-tears/
# 1006    https://asyafanatiklerim.com/dizi/pyramid-game/
# 1007    https://asyafanatiklerim.com/dizi/doctor-slump/
#
# [1008 rows x 4 columns]

# %%
year_counts = df.groupby('year').size()
year_counts
# Out:
# year
# 2010      8
# 2011     16
# 2012     13
# 2013     33
# 2014     51
# 2015     56
# 2016     98
# 2017    128
# 2018    122
# 2019    118
# 2020     93
# 2021     84
# 2022     85
# 2023     79
# 2024     24
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1008 entries, 0 to 1007
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    1008 non-null   object
#  1   rating  1008 non-null   float64
#  2   year    1008 non-null   int64
#  3   url     1008 non-null   object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 31.6+ KB

# %%
series = pd.read_csv("all_data.csv")
series
# Out:
#                                     name  total_episode  \
# 0                                P.S Man           21.0
# 1                         Because of You           22.0
# 2                      The Slave Hunters           24.0
# 3     My Girlfriend is a Nine-Tailed Fox           16.0
# 4                          Secret Garden           20.0
# ...                                  ...            ...
# 1003                 The Midnight Studio           16.0
# 1004                          Flex X Cop           16.0
# 1005                      Queen of Tears           16.0
# 1006                        Pyramid Game           10.0
# 1007                        Doctor Slump           16.0
#
#                                                    cast  \
# 0     [{'name': 'Sonia Sui', 'caracter': 'Ma Xiao Qi...
# 1     [{'name': 'Lego Lee Fang', 'caracter': 'Zi Hao...
# 2     [{'name': 'Jang Hyuk', 'caracter': 'Lee Dae-gi...
# 3     [{'name': 'Lee Seung-gi', 'caracter': 'Cha Dae...
# 4     [{'name': 'Hyun Bin', 'caracter': 'Kim Joo-won...
# ...                                                 ...
# 1003  [{'name': 'Joo Won', 'caracter': 'Seo Ki-joo'}...
# 1004  [{'name': 'Ahn Bo-hyun', 'caracter': 'Jin I-so...
# 1005  [{'name': 'Kim Soo-hyun', 'caracter': 'Baek Hy...
# 1006  [{'name': 'Bona', 'caracter': 'Sung Su-ji'}, {...
# 1007  [{'name': 'Park Shin-hye', 'caracter': 'Nam Ha...
#
#                                   category
# 0     Dram,Komedi,Romantik,Tayvan Dizileri
# 1         Gençlik,Romantik,Tayvan Dizileri
# 2                       Aksiyon,Dram,Tarih
# 3           Dram,Fantastik,Komedi,Romantik
# 4                    Dram,Fantastik,Komedi
# ...                                    ...
# 1003               Dram,Fantastik,Romantik
# 1004                     Aksiyon,Gizem,Suç
# 1005                         Dram,Romantik
# 1006          Aksiyon,Dram,Gençlik,Gerilim
# 1007                  Dram,Komedi,Romantik
#
# [1008 rows x 4 columns]

# %%
series.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1008 entries, 0 to 1007
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           1008 non-null   object
#  1   total_episode  932 non-null    float64
#  2   cast           973 non-null    object
#  3   category       1008 non-null   object
# dtypes: float64(1), object(3)
# memory usage: 31.6+ KB

# %%
merged_df = pd.merge(df, series, on='name')
merged_df
# Out:
#                                     name  rating  year  \
# 0                         Because of You     7.0  2010
# 1     My Girlfriend is a Nine-Tailed Fox     8.5  2010
# 2                                P.S Man     6.3  2010
# 3                       A Man Called God     6.7  2010
# 4                                  Pasta     7.4  2010
# ...                                  ...     ...   ...
# 1003                          Flex X Cop     9.1  2024
# 1004                 The Midnight Studio     8.0  2024
# 1005                      Queen of Tears     8.6  2024
# 1006                        Pyramid Game     8.7  2024
# 1007                        Doctor Slump     8.4  2024
#
#                                                     url  total_episode  \
# 0     https://asyafanatiklerim.com/dizi/because-of-you/           22.0
# 1     https://asyafanatiklerim.com/dizi/my-girlfrien...           16.0
# 2            https://asyafanatiklerim.com/dizi/p-s-man/           21.0
# 3     https://asyafanatiklerim.com/dizi/a-man-called...           24.0
# 4              https://asyafanatiklerim.com/dizi/pasta/           20.0
# ...                                                 ...            ...
# 1003      https://asyafanatiklerim.com/dizi/flex-x-cop/           16.0
# 1004  https://asyafanatiklerim.com/dizi/the-midnight...           16.0
# 1005  https://asyafanatiklerim.com/dizi/queen-of-tears/           16.0
# 1006    https://asyafanatiklerim.com/dizi/pyramid-game/           10.0
# 1007    https://asyafanatiklerim.com/dizi/doctor-slump/           16.0
#
#                                                    cast  \
# 0     [{'name': 'Lego Lee Fang', 'caracter': 'Zi Hao...
# 1     [{'name': 'Lee Seung-gi', 'caracter': 'Cha Dae...
# 2     [{'name': 'Sonia Sui', 'caracter': 'Ma Xiao Qi...
# 3     [{'name': 'Song Il-gook', 'caracter': 'Michael...
# 4     [{'name': 'Lee Sun-kyun', 'caracter': 'Choi Hy...
# ...                                                 ...
# 1003  [{'name': 'Ahn Bo-hyun', 'caracter': 'Jin I-so...
# 1004  [{'name': 'Joo Won', 'caracter': 'Seo Ki-joo'}...
# 1005  [{'name': 'Kim Soo-hyun', 'caracter': 'Baek Hy...
# 1006  [{'name': 'Bona', 'caracter': 'Sung Su-ji'}, {...
# 1007  [{'name': 'Park Shin-hye', 'caracter': 'Nam Ha...
#
#                                   category
# 0         Gençlik,Romantik,Tayvan Dizileri
# 1           Dram,Fantastik,Komedi,Romantik
# 2     Dram,Komedi,Romantik,Tayvan Dizileri
# 3                            Dram,Romantik
# 4                          Komedi,Romantik
# ...                                    ...
# 1003                     Aksiyon,Gizem,Suç
# 1004               Dram,Fantastik,Romantik
# 1005                         Dram,Romantik
# 1006          Aksiyon,Dram,Gençlik,Gerilim
# 1007                  Dram,Komedi,Romantik
#
# [1008 rows x 7 columns]

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1008 entries, 0 to 1007
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           1008 non-null   object
#  1   rating         1008 non-null   float64
#  2   year           1008 non-null   int64
#  3   url            1008 non-null   object
#  4   total_episode  932 non-null    float64
#  5   cast           973 non-null    object
#  6   category       1008 non-null   object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 55.3+ KB

# %%
merged_df["total_episode"] = merged_df["total_episode"].astype("Int64")

# %%
merged_df[merged_df["total_episode"].isna()]
# Out:
#                     name  rating  year  \
# 25           The Thieves     8.5  2012
# 86           Set Me Free     8.5  2014
# 136  Wonderful Nightmare     9.1  2015
# 242  After the Show Ends     8.2  2016
# 261       Train to Busan     9.2  2016
# ..                   ...     ...   ...
# 638                Money     8.9  2019
# 639   Miss and Mrs. Cops     9.4  2019
# 641    Hit and Run Squad     9.0  2019
# 642              Juror 8     9.3  2019
# 880      Confession 2022     8.5  2022
#
#                                                    url  total_episode  \
# 25   https://asyafanatiklerim.com/film/the-thieves-tr/           <NA>
# 86      https://asyafanatiklerim.com/film/set-me-free/           <NA>
# 136  https://asyafanatiklerim.com/film/wonderful-ni...           <NA>
# 242  https://asyafanatiklerim.com/dizi/after-the-sh...           <NA>
# 261  https://asyafanatiklerim.com/film/train-to-bus...           <NA>
# ..                                                 ...            ...
# 638           https://asyafanatiklerim.com/film/money/           <NA>
# 639  https://asyafanatiklerim.com/film/miss-and-mrs...           <NA>
# 641  https://asyafanatiklerim.com/film/hit-and-run-...           <NA>
# 642         https://asyafanatiklerim.com/film/juror-8/           <NA>
# 880  https://asyafanatiklerim.com/film/confession-2...           <NA>
#
#                                                   cast  \
# 25   [{'name': 'Choi Dong-hoon', 'caracter': 'Yönet...
# 86   [{'name': 'Kim Tae-yong', 'caracter': 'Yönetme...
# 136  [{'name': 'Kang Hyo-jin', 'caracter': 'Yönetme...
# 242  [{'name': 'Yoon So-hee', 'caracter': None}, {'...
# 261  [{'name': 'Yeon Sang-ho', 'caracter': 'Yönetme...
# ..                                                 ...
# 638  [{'name': 'Park Noo-ri', 'caracter': 'Yönetmen...
# 639  [{'name': None, 'caracter': 'Yönetmen'}, {'nam...
# 641  [{'name': None, 'caracter': 'Yönetmen'}, {'nam...
# 642  [{'name': None, 'caracter': 'Yönetmen'}, {'nam...
# 880  [{'name': 'Yoon Jong-seok', 'caracter': 'Yönet...
#
#                     category
# 25               Aksiyon,Suç
# 86                      Dram
# 136    Dram,Fantastik,Komedi
# 242  Dram,Fantastik,Romantik
# 261    Aksiyon,Gerilim,Korku
# ..                       ...
# 638                      Suç
# 639           Aksiyon,Komedi
# 641              Aksiyon,Suç
# 642             Dram,Gerilim
# 880        Gerilim,Gizem,Suç
#
# [76 rows x 7 columns]
