# %%
import pandas as pd
import numpy as np
import ast
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta

# %matplotlib inline

plt.rcParams["figure.figsize"]=(10,6)
sns.set_style("whitegrid")
pd.set_option("display.float_format", lambda x: '%.2f'  %x)

pd.options.display.max_rows=50
pd.options.display.max_columns=100

import warnings
warnings.filterwarnings("ignore")
warnings.warn("thisnwill not show")

# %%
series= pd.read_csv("series_by_year.csv")

# %%
series.drop("rating", axis=1, inplace=True )

# %%
informations = pd.read_csv("C:\\Users\\fzehr\\OneDrive\\Belgeler\\GitHub\\WebMiningProject\\asianfanatics\\a.csv")

# %%
merged_df = pd.merge(series, informations, on='name')
merged_df
# Out:
#                                     name  year  \
# 0                         Because of You  2010
# 1     My Girlfriend is a Nine-Tailed Fox  2010
# 2                                P.S Man  2010
# 3                       A Man Called God  2010
# 4                                  Pasta  2010
# ...                                  ...   ...
# 1003                          Flex X Cop  2024
# 1004                 The Midnight Studio  2024
# 1005                      Queen of Tears  2024
# 1006                        Pyramid Game  2024
# 1007                        Doctor Slump  2024
#
#                                                     url  total_episode  \
# 0     https://asyafanatiklerim.com/dizi/because-of-you/          22.00
# 1     https://asyafanatiklerim.com/dizi/my-girlfrien...          16.00
# 2            https://asyafanatiklerim.com/dizi/p-s-man/          21.00
# 3     https://asyafanatiklerim.com/dizi/a-man-called...          24.00
# 4              https://asyafanatiklerim.com/dizi/pasta/          20.00
# ...                                                 ...            ...
# 1003      https://asyafanatiklerim.com/dizi/flex-x-cop/          16.00
# 1004  https://asyafanatiklerim.com/dizi/the-midnight...          16.00
# 1005  https://asyafanatiklerim.com/dizi/queen-of-tears/          16.00
# 1006    https://asyafanatiklerim.com/dizi/pyramid-game/          10.00
# 1007    https://asyafanatiklerim.com/dizi/doctor-slump/          16.00
#
#       rating  like  watch                                               cast  \
# 0       7.00    11      3  [{'name': 'Lego Lee Fang', 'caracter': 'Zi Hao...
# 1       8.50   119    105  [{'name': 'Lee Seung-gi', 'caracter': 'Cha Dae...
# 2       6.30    17     16  [{'name': 'Sonia Sui', 'caracter': 'Ma Xiao Qi...
# 3       6.70    10      9  [{'name': 'Song Il-gook', 'caracter': 'Michael...
# 4       7.40    22     22  [{'name': 'Lee Sun-kyun', 'caracter': 'Choi Hy...
# ...      ...   ...    ...                                                ...
# 1003    9.10    77     32  [{'name': 'Ahn Bo-hyun', 'caracter': 'Jin I-so...
# 1004    8.00    62     28  [{'name': 'Joo Won', 'caracter': 'Seo Ki-joo'}...
# 1005    8.60    58     36  [{'name': 'Kim Soo-hyun', 'caracter': 'Baek Hy...
# 1006    8.70    46     12  [{'name': 'Bona', 'caracter': 'Sung Su-ji'}, {...
# 1007    8.40    81     44  [{'name': 'Park Shin-hye', 'caracter': 'Nam Ha...
#
#                                   category
# 0         Gençlik,Romantik,Tayvan Dizileri
# 1           Dram,Fantastik,Komedi,Romantik
# 2     Dram,Komedi,Romantik,Tayvan Dizileri
# 3                            Dram,Romantik
# 4                          Komedi,Romantik
# ...                                    ...
# 1003                     Aksiyon,Gizem,Suç
# 1004               Dram,Fantastik,Romantik
# 1005                         Dram,Romantik
# 1006          Aksiyon,Dram,Gençlik,Gerilim
# 1007                  Dram,Komedi,Romantik
#
# [1008 rows x 9 columns]

# %%
year_counts = merged_df.groupby('year').size()
year_counts
# Out:
# year
# 2010      8
# 2011     16
# 2012     13
# 2013     33
# 2014     51
# 2015     56
# 2016     98
# 2017    128
# 2018    122
# 2019    118
# 2020     93
# 2021     84
# 2022     85
# 2023     79
# 2024     24
# dtype: int64

# %%
merged_df[merged_df["total_episode"].isna()]
# Out:
#                     name  year  \
# 25           The Thieves  2012
# 86           Set Me Free  2014
# 136  Wonderful Nightmare  2015
# 242  After the Show Ends  2016
# 261       Train to Busan  2016
# ..                   ...   ...
# 638                Money  2019
# 639   Miss and Mrs. Cops  2019
# 641    Hit and Run Squad  2019
# 642              Juror 8  2019
# 880      Confession 2022  2022
#
#                                                    url  total_episode  rating  \
# 25   https://asyafanatiklerim.com/film/the-thieves-tr/            NaN    8.50
# 86      https://asyafanatiklerim.com/film/set-me-free/            NaN    8.50
# 136  https://asyafanatiklerim.com/film/wonderful-ni...            NaN    9.10
# 242  https://asyafanatiklerim.com/dizi/after-the-sh...            NaN    8.20
# 261  https://asyafanatiklerim.com/film/train-to-bus...            NaN    9.20
# ..                                                 ...            ...     ...
# 638           https://asyafanatiklerim.com/film/money/            NaN    8.90
# 639  https://asyafanatiklerim.com/film/miss-and-mrs...            NaN    9.40
# 641  https://asyafanatiklerim.com/film/hit-and-run-...            NaN    9.00
# 642         https://asyafanatiklerim.com/film/juror-8/            NaN    9.30
# 880  https://asyafanatiklerim.com/film/confession-2...            NaN    8.50
#
#      like  watch                                               cast  \
# 25     61     35  [{'name': 'Choi Dong-hoon', 'caracter': 'Yönet...
# 86     12      9  [{'name': 'Kim Tae-yong', 'caracter': 'Yönetme...
# 136    17     21  [{'name': 'Kang Hyo-jin', 'caracter': 'Yönetme...
# 242    77     37  [{'name': 'Yoon So-hee', 'caracter': None}, {'...
# 261   232    188  [{'name': 'Yeon Sang-ho', 'caracter': 'Yönetme...
# ..    ...    ...                                                ...
# 638    27     20  [{'name': 'Park Noo-ri', 'caracter': 'Yönetmen...
# 639   196    111  [{'name': None, 'caracter': 'Yönetmen'}, {'nam...
# 641    47     33  [{'name': None, 'caracter': 'Yönetmen'}, {'nam...
# 642    48     31  [{'name': None, 'caracter': 'Yönetmen'}, {'nam...
# 880    33      7  [{'name': 'Yoon Jong-seok', 'caracter': 'Yönet...
#
#                     category
# 25               Aksiyon,Suç
# 86                      Dram
# 136    Dram,Fantastik,Komedi
# 242  Dram,Fantastik,Romantik
# 261    Aksiyon,Gerilim,Korku
# ..                       ...
# 638                      Suç
# 639           Aksiyon,Komedi
# 641              Aksiyon,Suç
# 642             Dram,Gerilim
# 880        Gerilim,Gizem,Suç
#
# [76 rows x 9 columns]

# %% [markdown]
# ## Filled nan values in total_episode

# %%
merged_df.loc[merged_df["url"].str.contains("/film"), "total_episode"] = merged_df.loc[merged_df["url"].str.contains("/film"), "total_episode"].fillna(1)

# %%
merged_df[merged_df["total_episode"].isna()]
# Out:
#                         name  year  \
# 242      After the Show Ends  2016
# 311  Bir Doksan (One Ninety)  2017
# 443                    Smile  2018
# 604                  Kill It  2019
#
#                                                    url  total_episode  rating  \
# 242  https://asyafanatiklerim.com/dizi/after-the-sh...            NaN    8.20
# 311  https://asyafanatiklerim.com/dizi/bir-doksan-o...            NaN    7.80
# 443           https://asyafanatiklerim.com/dizi/smile/            NaN    8.80
# 604         https://asyafanatiklerim.com/dizi/kill-it/            NaN    9.30
#
#      like  watch                                               cast  \
# 242    77     37  [{'name': 'Yoon So-hee', 'caracter': None}, {'...
# 311    77     49                                                NaN
# 443   152     86                                                NaN
# 604   298    162  [{'name': 'Jang Ki-Yong', 'caracter': 'Kim Soo...
#
#                                         category
# 242                      Dram,Fantastik,Romantik
# 311  Gençlik,Kazakistan Dizileri,Komedi,Romantik
# 443                 Çin Dizileri,Komedi,Romantik
# 604                                Aksiyon,Gizem

# %%
merged_df.loc[merged_df["name"] == "After the Show Ends", "total_episode"] = merged_df.loc[merged_df["name"] == "After the Show Ends", "total_episode"].fillna(8)
merged_df.loc[merged_df["name"] == "Bir Doksan (One Ninety)	", "total_episode"] = merged_df.loc[merged_df["name"] == "Bir Doksan (One Ninety)	", "total_episode"].fillna(5)
merged_df.loc[merged_df["name"] == "Smile", "total_episode"] = merged_df.loc[merged_df["name"] == "Smile", "total_episode"].fillna(24)
merged_df.loc[merged_df["name"] == "Kill It	", "total_episode"] = merged_df.loc[merged_df["name"] == "Kill It	", "total_episode"].fillna(12)

# %%
merged_df["total_episode"] = merged_df["total_episode"].astype("Int64")

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1008 entries, 0 to 1007
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           1008 non-null   object
#  1   year           1008 non-null   int64
#  2   url            1008 non-null   object
#  3   total_episode  1006 non-null   Int64
#  4   rating         1008 non-null   float64
#  5   like           1008 non-null   int64
#  6   watch          1008 non-null   int64
#  7   cast           973 non-null    object
#  8   category       1008 non-null   object
# dtypes: Int64(1), float64(1), int64(3), object(4)
# memory usage: 72.0+ KB

# %% [markdown]
# ## create new column by movie or serie

# %%
def determine_type(url):
    if "/film" in url:
        return "Movie"
    else:
        return "Series"

merged_df["type"] = merged_df["url"].apply(determine_type)

# %%
sns.pairplot(merged_df);

# %% [markdown]
# ## Cast column was split

# %%
data = []

for i, entry in enumerate(merged_df["cast"]):
    if not pd.isna(entry):
        for cast_dict in ast.literal_eval(entry):
            name = cast_dict['name']
            character = cast_dict['caracter']
            series_name = merged_df.loc[i, "name"]  
            data.append({"Name": name, "Character": character, "Series": series_name})

cast_df = pd.DataFrame(data)

cast_df
# Out:
#                Name      Character                              Series
# 0     Lego Lee Fang         Zi Hao                      Because of You
# 1         Megan Lai    Yu You Tong                      Because of You
# 2        Baron Chen        Sun Fan                      Because of You
# 3      Lee Seung-gi  Cha Dae-woong  My Girlfriend is a Nine-Tailed Fox
# 4        Shin Min-A       Gu Mi-ho  My Girlfriend is a Nine-Tailed Fox
# ...             ...            ...                                 ...
# 7600      Yoon Park  Bin Dae-young                        Doctor Slump
# 7601  Kong Seong-ha   Lee Hong-ran                        Doctor Slump
# 7602    Park Won-ho       Moo-geun                        Doctor Slump
# 7603  Hyun Bong-sik       Tae-seon                        Doctor Slump
# 7604   Jang Hye-jin       Ha-neul'                        Doctor Slump
#
# [7605 rows x 3 columns]

# %%
cast_df["Name"].value_counts()
# Out:
# Name
# Kim Won-hae        22
# Sung Dong-il       21
# Kim Sang-ho        19
# Ahn Nae-sang       17
# Kim Hae-sook       17
#                    ..
# Samuel              1
# Lee Hyeong-seok     1
# Kim Yong-jin        1
# Jo Seung-Hee        1
# Park Won-ho         1
# Name: count, Length: 3119, dtype: int64

# %%
actor_counts = cast_df['Name'].value_counts()

top_actors = actor_counts[actor_counts > 14]

#These 4 blocks of code are related to creating colors. because some actors have played in the same number of plays
unique_counts = top_actors.unique()
color_palette = sns.color_palette("hsv", len(unique_counts))
color_dict = {count: color_palette[i] for i, count in enumerate(unique_counts)}
colors = [color_dict[count] for count in top_actors]

plt.figure(figsize=(10, 6))
top_actors.plot.pie(autopct='%1.1f%%', startangle=140, colors = colors)
plt.title('Top 10 Actors by Number of Series')
plt.ylabel('')  # Y label'ı gizle
plt.show()

# %% [markdown]
# # We splited the category list and counted how many there were

# %%
from collections import Counter

categories_list = []

for cat_string in merged_df["category"]:
    categories = cat_string.split(",")
    
    for category in categories:
        # Boşlukları temizleyin
        category = category.strip().lower()
        
        # Kategoriyi listeye ekleyin
        categories_list.append(category)

# Kategorilerin sayısını hesaplayın
category_counts = Counter(categories_list)

# Kategorilerin sayısını yazdırın
for category, count in category_counts.items():
    print(f"{category}: {count}")
# Out:
# gençlik: 120
# romantik: 571
# tayvan dizileri: 25
# dram: 609
# fantastik: 205
# komedi: 379
# aksiyon: 173
# tarih: 92
# tayland dizileri: 20
# suç: 109
# aile: 63
# japon dizileri: 26
# gizem: 201
# medikal: 23
# gerilim: 104
# hukuk: 41
# animasyon: 35
# anime: 38
# bilim kurgu: 39
# macera: 9
# korku: 13
# çin dizileri: 54
# polisiye: 10
# aksiyon & macera: 6
# tv show: 3
# kazakistan dizileri: 1
# savaş: 8
# spor: 3
# gerçeklik: 1
# belgesel: 1

# %%
merged_df
# Out:
#                                     name  year  \
# 0                         Because of You  2010
# 1     My Girlfriend is a Nine-Tailed Fox  2010
# 2                                P.S Man  2010
# 3                       A Man Called God  2010
# 4                                  Pasta  2010
# ...                                  ...   ...
# 1003                          Flex X Cop  2024
# 1004                 The Midnight Studio  2024
# 1005                      Queen of Tears  2024
# 1006                        Pyramid Game  2024
# 1007                        Doctor Slump  2024
#
#                                                     url  total_episode  \
# 0     https://asyafanatiklerim.com/dizi/because-of-you/             22
# 1     https://asyafanatiklerim.com/dizi/my-girlfrien...             16
# 2            https://asyafanatiklerim.com/dizi/p-s-man/             21
# 3     https://asyafanatiklerim.com/dizi/a-man-called...             24
# 4              https://asyafanatiklerim.com/dizi/pasta/             20
# ...                                                 ...            ...
# 1003      https://asyafanatiklerim.com/dizi/flex-x-cop/             16
# 1004  https://asyafanatiklerim.com/dizi/the-midnight...             16
# 1005  https://asyafanatiklerim.com/dizi/queen-of-tears/             16
# 1006    https://asyafanatiklerim.com/dizi/pyramid-game/             10
# 1007    https://asyafanatiklerim.com/dizi/doctor-slump/             16
#
#       rating  like  watch                                               cast  \
# 0       7.00    11      3  [{'name': 'Lego Lee Fang', 'caracter': 'Zi Hao...
# 1       8.50   119    105  [{'name': 'Lee Seung-gi', 'caracter': 'Cha Dae...
# 2       6.30    17     16  [{'name': 'Sonia Sui', 'caracter': 'Ma Xiao Qi...
# 3       6.70    10      9  [{'name': 'Song Il-gook', 'caracter': 'Michael...
# 4       7.40    22     22  [{'name': 'Lee Sun-kyun', 'caracter': 'Choi Hy...
# ...      ...   ...    ...                                                ...
# 1003    9.10    77     32  [{'name': 'Ahn Bo-hyun', 'caracter': 'Jin I-so...
# 1004    8.00    62     28  [{'name': 'Joo Won', 'caracter': 'Seo Ki-joo'}...
# 1005    8.60    58     36  [{'name': 'Kim Soo-hyun', 'caracter': 'Baek Hy...
# 1006    8.70    46     12  [{'name': 'Bona', 'caracter': 'Sung Su-ji'}, {...
# 1007    8.40    81     44  [{'name': 'Park Shin-hye', 'caracter': 'Nam Ha...
#
#                                   category    type  category_count
# 0         Gençlik,Romantik,Tayvan Dizileri  Series               3
# 1           Dram,Fantastik,Komedi,Romantik  Series               4
# 2     Dram,Komedi,Romantik,Tayvan Dizileri  Series               4
# 3                            Dram,Romantik  Series               2
# 4                          Komedi,Romantik  Series               2
# ...                                    ...     ...             ...
# 1003                     Aksiyon,Gizem,Suç  Series               3
# 1004               Dram,Fantastik,Romantik  Series               3
# 1005                         Dram,Romantik  Series               2
# 1006          Aksiyon,Dram,Gençlik,Gerilim  Series               4
# 1007                  Dram,Komedi,Romantik  Series               3
#
# [1008 rows x 11 columns]

# %%
categories_list = []

for cat_string in merged_df["category"]:
    categories = cat_string.split(",")
    
    for category in categories:
        # Boşlukları temizleyin
        category = category.strip().lower()
        
        # Kategoriyi listeye ekleyin
        categories_list.append(category)

# Kategorilerin sayısını hesaplayın
category_counts = Counter(categories_list)
#The series has that how many category
merged_df["category_count"] = merged_df["category"].apply(lambda x: len(x.split(",")))

# %%
merged_df
# Out:
#                                     name  year  \
# 0                         Because of You  2010
# 1     My Girlfriend is a Nine-Tailed Fox  2010
# 2                                P.S Man  2010
# 3                       A Man Called God  2010
# 4                                  Pasta  2010
# ...                                  ...   ...
# 1003                          Flex X Cop  2024
# 1004                 The Midnight Studio  2024
# 1005                      Queen of Tears  2024
# 1006                        Pyramid Game  2024
# 1007                        Doctor Slump  2024
#
#                                                     url  total_episode  \
# 0     https://asyafanatiklerim.com/dizi/because-of-you/             22
# 1     https://asyafanatiklerim.com/dizi/my-girlfrien...             16
# 2            https://asyafanatiklerim.com/dizi/p-s-man/             21
# 3     https://asyafanatiklerim.com/dizi/a-man-called...             24
# 4              https://asyafanatiklerim.com/dizi/pasta/             20
# ...                                                 ...            ...
# 1003      https://asyafanatiklerim.com/dizi/flex-x-cop/             16
# 1004  https://asyafanatiklerim.com/dizi/the-midnight...             16
# 1005  https://asyafanatiklerim.com/dizi/queen-of-tears/             16
# 1006    https://asyafanatiklerim.com/dizi/pyramid-game/             10
# 1007    https://asyafanatiklerim.com/dizi/doctor-slump/             16
#
#       rating  like  watch                                               cast  \
# 0       7.00    11      3  [{'name': 'Lego Lee Fang', 'caracter': 'Zi Hao...
# 1       8.50   119    105  [{'name': 'Lee Seung-gi', 'caracter': 'Cha Dae...
# 2       6.30    17     16  [{'name': 'Sonia Sui', 'caracter': 'Ma Xiao Qi...
# 3       6.70    10      9  [{'name': 'Song Il-gook', 'caracter': 'Michael...
# 4       7.40    22     22  [{'name': 'Lee Sun-kyun', 'caracter': 'Choi Hy...
# ...      ...   ...    ...                                                ...
# 1003    9.10    77     32  [{'name': 'Ahn Bo-hyun', 'caracter': 'Jin I-so...
# 1004    8.00    62     28  [{'name': 'Joo Won', 'caracter': 'Seo Ki-joo'}...
# 1005    8.60    58     36  [{'name': 'Kim Soo-hyun', 'caracter': 'Baek Hy...
# 1006    8.70    46     12  [{'name': 'Bona', 'caracter': 'Sung Su-ji'}, {...
# 1007    8.40    81     44  [{'name': 'Park Shin-hye', 'caracter': 'Nam Ha...
#
#                                   category    type  category_count
# 0         Gençlik,Romantik,Tayvan Dizileri  Series               3
# 1           Dram,Fantastik,Komedi,Romantik  Series               4
# 2     Dram,Komedi,Romantik,Tayvan Dizileri  Series               4
# 3                            Dram,Romantik  Series               2
# 4                          Komedi,Romantik  Series               2
# ...                                    ...     ...             ...
# 1003                     Aksiyon,Gizem,Suç  Series               3
# 1004               Dram,Fantastik,Romantik  Series               3
# 1005                         Dram,Romantik  Series               2
# 1006          Aksiyon,Dram,Gençlik,Gerilim  Series               4
# 1007                  Dram,Komedi,Romantik  Series               3
#
# [1008 rows x 11 columns]

# %%
merged_df.groupby("year")["rating"].max()
# Out:
# year
# 2010   8.90
# 2011   9.40
# 2012   9.00
# 2013   9.40
# 2014   9.40
# 2015   9.40
# 2016   9.60
# 2017   9.60
# 2018   9.40
# 2019   9.50
# 2020   9.60
# 2021   9.50
# 2022   9.60
# 2023   9.60
# 2024   9.40
# Name: rating, dtype: float64

# %%
sns.histplot(x=merged_df.groupby("year")["rating"].max())
plt.title('')
plt.xlabel('CO2 Emisyonu')
plt.ylabel('Density')
plt.show()
